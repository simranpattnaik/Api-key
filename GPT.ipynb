# %%
pip install -U "langchain[google-genai]"
# Out:
# ...
#   Using cached langchain_google_genai-4.2.1-py3-none-any.whl.metadata (2.7 kB)
# ...
#    ---------------------------------------- 0.0/732.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/732.2 kB ? eta -:--:--
#    -------------- ------------------------- 262.1/732.2 kB ? eta -:--:--
#    --------------------------- ---------- 524.3/732.2 kB 932.9 kB/s eta 0:00:01
#    ---------------------------------------- 732.2/732.2 kB 1.1 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.5 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.5 MB ? eta -:--:--
#    ------ --------------------------------- 0.5/3.5 MB 558.9 kB/s eta 0:00:06
#    --------- ------------------------------ 0.8/3.5 MB 699.0 kB/s eta 0:00:04
# ...

# %%
import os
from langchain.chat_models import init_chat_model
os.environ["GOOGLE_API_KEY"]='AIzaSyAxabxUHU5lXi0ubFsv9YRdlPv631AImzU'
model=init_chat_model("google_genai:gemini-2.5-flash-lite")

# %%
response = model.invoke('About odisha')

# %%
response
# Out:
# AIMessage(content='Odisha is a fascinating state in eastern India, rich in history, culture, art, and natural beauty. Here\'s a comprehensive overview:\n\n**Geography and Location:**\n\n*   **Location:** Situated on the eastern coast of India, bordering West Bengal to the north-east, Jharkhand to the north, Chhattisgarh to the west, Andhra Pradesh to the south, and the Bay of Bengal to the east.\n*   **Capital:** Bhubaneswar.\n*   **Key Cities:** Cuttack, Rourkela, Berhampur, Sambalpur, Puri.\n*   **Terrain:** A diverse landscape featuring a long coastline, fertile river valleys (Mahanadi, Brahmani, Baitarani), extensive forests, and a plateau region in the western part.\n*   **Natural Resources:** Rich in mineral resources like iron ore, coal, bauxite, chromite, manganese, and limestone. It also has significant forest cover.\n\n**History and Heritage:**\n\n*   **Ancient Roots:** Odisha\'s history dates back to the Kalinga Empire, which rose to prominence in the 3rd century BCE. The 
# ...

# %%
from langchain_core.messages import HumanMessage,SystemMessage
message=[
    SystemMessage('translate the following from English into odia language'),
    HumanMessage('good  things are coming your way'),
]
model.invoke(message)
# Out:
# AIMessage(content='"Good things are coming your way" - ଏହି ବାକ୍ୟର ଓଡ଼ିଆ ଅନୁବାଦ ହେଉଛି:\n\n**"ଆପଣଙ୍କ ଆଡ଼କୁ ଭଲ ଜିନିଷ ଆସୁଛି।"**\n\nଏହା ବ୍ୟତୀତ, ଆପଣ ଏହିଭଳି ମଧ୍ୟ କହିପାରିବେ:\n\n*   **"ଆପଣଙ୍କ ପାଇଁ ଭଲ ସମୟ ଆସୁଛି।"** (This implies good times are coming)\n*   **"ଆପଣଙ୍କ ପାଇଁ ଶୁଭ ଖବର ଆସୁଛି।"** (This implies good news is coming)', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019cceb9-32d2-7393-842a-f12f7c0d30d4-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 17, 'output_tokens': 147, 'total_tokens': 164, 'input_token_details': {'cache_read': 0}})
